# %% [markdown]
# **DATA EXPLORATION**

# %%
import pandas as pd 
df = pd.read_excel('data_rumah.xlsx')
print(df.head())
# Out:
#    Unnamed: 0                                              judul
# 0           0                      Promo Rumah Mewah Akhir Tahun  \
# 1           1  Rumah modern Readystock di bandung raya cimahi...
# 2           2  Dijual rumah 300 jutaan jalan lebar dekat Ikea...
# 3           3  Dijual PROMO rumah 2 lantai di sayap Setiabudi...
# 4           4  Rumah Strategis Siap Huni di dekat Tol Cileuny...
#
#                    alamat                                          deskripsi
# 0       Antapani, Bandung  Promo akhir tahun !! Hanya 500 jt-an + FREE SH...  \
# 1  Bandung Wetan, Bandung  Rumah Baru modern 2 LT di Sayap Kota Cimahi de...
# 2     Padalarang, Bandung  *Jadilah konsumen CERDAS !* *Tips singkat sebe...
# 3                 Bandung  Copy writing nasc  NUANSA ALAM SETIABUDHI CLOV...
# 4   Cibiru Hilir, Bandung  Hunian Nyaman di Cibiru, Cileunyi, Bandung Tim...
#
#    kamar  bangunan  lahan      harga
# 0      3        75     84  590000000
# 1      3        70     71  700000000
# 2      2        36     72  386000000
# 3      2        60     60  499000000
# 4      2        90    114  397500000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  1470 non-null   int64
#  1   judul       1470 non-null   object
#  2   alamat      1470 non-null   object
#  3   deskripsi   1468 non-null   object
#  4   kamar       1470 non-null   int64
#  5   bangunan    1470 non-null   int64
#  6   lahan       1470 non-null   int64
#  7   harga       1470 non-null   int64
# dtypes: int64(5), object(3)
# memory usage: 92.0+ KB

# %%
df.describe()
# Out:
#         Unnamed: 0        kamar     bangunan         lahan         harga
# count  1470.000000  1470.000000  1470.000000   1470.000000  1.470000e+03
# mean    734.500000     3.646259   177.489116    210.235374  2.581586e+09
# std     424.496761     2.535528   176.726326    500.109095  4.358051e+09
# min       0.000000     0.000000     0.000000      0.000000  6.500000e+07
# 25%     367.250000     2.000000    65.000000     80.000000  6.750000e+08
# 50%     734.500000     3.000000   122.500000    120.000000  1.370000e+09
# 75%    1101.750000     4.000000   230.000000    210.000000  3.000000e+09
# max    1469.000000    47.000000  1850.000000  15000.000000  5.700000e+10

# %%
df.describe(include='object')
# Out:
#                                                     judul   alamat
# count                                                1470     1470  \
# unique                                               1431      140
# top     Rumah Pusat Kota, sayap Martanegara Bandung, J...  Bandung
# freq                                                    3      253
#
#                                                 deskripsi
# count                                                1468
# unique                                               1418
# top     BUMI KRESNA ASRI   Jln. Terusan Cibaduyut Ranc...
# freq                                                    5

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'judul', 'alamat', 'deskripsi', 'kamar', 'bangunan',
#        'lahan', 'harga'],
#       dtype='object')

# %%
df.shape
# Out:
# (1470, 8)

# %%
df.columns = ['ID', 'judul', 'alamat', 'deskripsi', 'kamar', 'luas_bangunan','luas_lahan', 'harga']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ID             1470 non-null   int64
#  1   judul          1470 non-null   object
#  2   alamat         1470 non-null   object
#  3   deskripsi      1468 non-null   object
#  4   kamar          1470 non-null   int64
#  5   luas_bangunan  1470 non-null   int64
#  6   luas_lahan     1470 non-null   int64
#  7   harga          1470 non-null   int64
# dtypes: int64(5), object(3)
# memory usage: 92.0+ KB

# %% [markdown]
# *Histogram untuk Distribusi Harga*

# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))
plt.hist(df['harga'], bins=20, color='green', edgecolor='black')
plt.title('Distribusi Harga Rumah')
plt.xlabel('Harga (IDR)')
plt.ylabel('Frekuensi')
plt.show()

# %% [markdown]
# *Scatter Plot Hubungan antara Luas Bangunan VS Harga*

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.scatter(df['luas_bangunan'], df['harga'], color='blue', alpha=0.6, edgecolor='black')
plt.title('Luas Bangunan VS Harga Rumah', fontsize=16)
plt.xlabel('Luas Bangunan (m²)', fontsize=12)
plt.ylabel('Harga (IDR)', fontsize=12)

plt.grid(linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# *hubungan antar variabel numerik jumlah kamar, luas bangunan, luas lahan, dan harga*

# %%
correlation_matrix = df[['kamar', 'luas_bangunan', 'luas_lahan', 'harga']].corr()

plt.figure(figsize=(8,6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Heat Map Korelasi Antar Variabel Numerik')
plt.show()

# %% [markdown]
# *Bar Chart untuk Jumlah Rumah per Lokasi*

# %%
rumah_per_alamat = df['alamat'].value_counts()

plt.figure(figsize=(12,8))
rumah_per_alamat.plot(kind='bar', color='coral')
plt.title('Jumlah Rumah per Lokasi')
plt.xlabel('Lokasi')
plt.ylabel('Jumlah Rumah')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# *Outlier Harga*

# %%
import pandas as pd

Q1 = df['harga'].quantile(0.25)  
Q3 = df['harga'].quantile(0.75) 
IQR = Q3 - Q1                    

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
outliers = df[(df['harga'] < lower_bound) | (df['harga'] > upper_bound)]

print("Jumlah outlier pada kolom harga:", len(outliers))
print("Batas bawah:", lower_bound)
print("Batas atas:", upper_bound)
print("\nOutlier pada kolom harga:")
print(outliers)
# Out:
# Jumlah outlier pada kolom harga: 106
# Batas bawah: -2812500000.0
# Batas atas: 6487500000.0
#
# Outlier pada kolom harga:
#         ID                                              judul
# 8        8  LANGKA!!! Dijual rumah kos strategis lokasi pr...  \
# 14      14  STRATEGIS!!! Dijual rumah murah sayap setrasar...
# 142    142  HUNIAN MEWAH BERKONSEP  DESIGN ARCHITECTURAL D...
# 162    162  Dijual Kos Kosan "Sweet Home" di Bandung Lokas...
# 181    181             Rumah Mewah di Sayap Cipaganti Bandung
# ...    ...                                                ...
# 1395  1395  DIJUAL Rumah Lux Minimalis di Setiabudi Regenc...
# 1407  1407                                Rumah di Sayap Riau
# 1437  1437  Jual Rumah Siap Huni Full Furnished Dago Pakar...
# 1443  1443  Jual Rumah Siap Huni Full Furnished Dago Pakar...
# 1456  1456  Rumah eklusif bangun sangat bagus terawat loka...
#
#                     alamat                                          deskripsi
# 8            Dago, Bandung  LANGKA!!! Dijual rumah kos strategis lokasi pr...  \
# 14    Gegerkalong, Bandung  STRATEGIS!!! Dijual rumah murah sayap setrasar...
# 142          Dago, Bandung  CRAZY RICH DAGO RESORT Oleh PT. ESHAN REALTY I...
# 162   Dayeuhkolot, Bandung  Dijual Kos kosan di Bandung SHM.  Luas Tanah :...
# 181     Cipaganti, Bandung  Rumah Mewah di Sayap Cipaganti,lokasi ok. Bisa...
# ...                    ...                                                ...
# 1395      Cidadap, Bandung  Rumah Setiabudi Regency Luas tanah 890 mtr Lua...
# 1407         Riau, Bandung  Dijual rumah di sayap Riau LT 734 m LB 350 m L...
# 1437               Bandung  Jual Rumah Siap Huni Full Furnished Dago Pakar...
# 1443               Bandung  Jual Rumah Siap Huni Full Furnished Dago Pakar...
# 1456     Sukasari, Bandung  Jual Rumah Mewah MinimalisKomplek SetramurniKo...
#
#       kamar  luas_bangunan  luas_lahan        harga
# 8         7            200         620  22500000000
# 14        7            670         620  10000000000
# 142       4            200         500   8100000000
# 162      23           1085         385   9500000000
# 181       7            800         830  21000000000
# ...     ...            ...         ...          ...
# 1395      5            650         890   7000000000
# 1407      4            350         734  17000000000
# 1437      5            350         490   6700000000
# 1443      5            350         490   6700000000
# 1456      4            500         536   9000000000
#
# [106 rows x 8 columns]

# %% [markdown]
# *Visualisasi outlier Harga*

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
sns.boxplot(data=df, y='harga', color='green')
plt.title('Boxplot Harga Rumah')
plt.ylabel('Harga (IDR)')
plt.show()

# %% [markdown]
# *Outlier Kamar*

# %%
import pandas as pd

Q1 = df['kamar'].quantile(0.25)  
Q3 = df['kamar'].quantile(0.75) 
IQR = Q3 - Q1                    

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
outliers = df[(df['kamar'] < lower_bound) | (df['kamar'] > upper_bound)]

print("Jumlah outlier pada kolom kamar:", len(outliers))
print("Batas bawah:", lower_bound)
print("Batas atas:", upper_bound)
print("\nOutlier pada kolom kamar:")
print(outliers)
# Out:
# Jumlah outlier pada kolom kamar: 47
# Batas bawah: -1.0
# Batas atas: 7.0
#
# Outlier pada kolom kamar:
#         ID                                              judul
# 38      38  Rumah Kost Bangunan Baru + Kios Turun Harga di...  \
# 118    118  Jual murah rumah minimalis, Mekar Wangi, Bandu...
# 134    134  JUAL Rumah SEHAT  2 Lantai di SETIABUDI REGENC...
# 162    162  Dijual Kos Kosan "Sweet Home" di Bandung Lokas...
# 218    218           Rumah di sayap dago sultan agung bandung
# 220    220  For Sale Rumah di Setiabudi, Cipaganti Apprais...
# 256    256  Rumah Kost Dekat Samsat Soekarno Hatta Bypass ...
# 282    282  Readystock Rumah Nuansa Islami Lembang Bandung...
# 305    305  Rumah Kost Siap Pakai di Dekat STT Telkom Tol ...
# 313    313  Rumah dijual murah di Buahbatu Bandung, luas b...
# 330    330  Rumah Semi minimalis di Sarikaso, Sarijadi, co...
# 338    338  Rumah hot istimewa di jl Taman Pramuka kota Ba...
# 359    359               Jual Rumah Pilar Biru  Bandung timur
# 390    390          Dijual kost2an syp pjjran Bandung - Henny
# 399    399   Dijual Rumah di Komplek Logam, buah batu Bandung
# 404    404  JUAL CEPAT RUMAH SECOND MULTIFUNGSI LOKASI STR...
# 440    440           DIJUAL RUMAH BERHALAMAN LUAS DI CIBEREUM
# 443    443  Dijual Rumah Kost Komplek Muara Bandung Dekat ...
# 495    495                          Kost-Kostan di Jatinangor
# 507    507  Rumah di cipedes selatan dekat hotel aston LM ...
# 567    567  Kost Aktif Jatinangor Bandung Dekat Kampus, Fu...
# 603    603  Hotel melati aktif di turangga lengkong bagus ...
# 638    638  Tanah Ngantong Bonus Bangunan di Sayap Dago De...
# 669    669  Rumah di Lembah Permai Hanjuang, Lingkungan as...
# 670    670  Rumah Besar Mewah Di Jual Murah Di Cisaranten ...
# 678    678                 Rumah Strategis Nyaman - Bumi Asri
# 694    694                         Rumah Terawat Di Cipaganti
# 739    739  Dijual Rumah Area Cipaganti Bandung Lokasi Str...
# 824    824  Rumah Mewah Konsep Syariah plus Furniture di L...
# 855    855                       RUMAH JL SADANG SARI BANDUNG
# 933    933  Rumah kost luxuary, super premium di Ciumbuleu...
# 1028  1028                     Rumah mewah dan udaranya alami
# 1059  1059                     Dijual Rumah Sayap BKR Bandung
# 1062  1062  Dijual Rumah Hitung Tanah Mainroad Gatot Subro...
# 1091  1091  Murah !! kost aktif untuk invest dekat kampus ...
# 1098  1098  Dago - Komplek Elite, Bangunan Mevvah, Harga D...
# 1192  1192  Jual tanah 540 M2 hanya 1,4 Milyar bonus 4 rum...
# 1252  1252  Rumah Kost Terawat di Sukaresik, Sayap Babakan...
# 1290  1290     Jual Cepat Muraah Villa Lembang Cikole Bandung
# 1298  1298                   Rumah Mewah Supratman Sayap Riau
# 1326  1326  JUAL RUMAH 2LANTAI DI JL BUDI INDAH LEDENG CID...
# 1347  1347  Dijual Rumah Mainroad Sayap Riau. Cocok Untuk ...
# 1386  1386  Dijual Rumah Mewah Di Pusat Kota  Buahbatu Hal...
# 1404  1404  Dijual Rumah Dekat Istana Plaza Pajajaran Bandung
# 1417  1417  Rumah Kosan Aktif Lokasi Stategis Perumahan Cl...
# 1434  1434  Rumah Mewah Siap Huni Cipaku Indah, Kotamadya ...
# 1450  1450  Rumah Mewah Siap Huni Cipaku Indah, Kotamadya ...
#
#                               alamat
# 38                Sukamenak, Bandung  \
# 118              Mekarwangi, Bandung
# 134               Setiabudi, Bandung
# 162             Dayeuhkolot, Bandung
# 218                    Dago, Bandung
# 220               Setiabudi, Bandung
# 256                Buahbatu, Bandung
# 282                 Lembang, Bandung
# 305             Bojongsoang, Bandung
# 313                Buahbatu, Bandung
# 330                          Bandung
# 338           Bandung Wetan, Bandung
# 359                  Cibiru, Bandung
# 390               Pajajaran, Bandung
# 399   Buahbatu (Margacinta), Bandung
# 404                    Kopo, Bandung
# 440                Paledang, Bandung
# 443         Bojongloa Kidul, Bandung
# 495              Jatinangor, Bandung
# 507                 Pasteur, Bandung
# 567              Jatinangor, Bandung
# 603                Turangga, Bandung
# 638                          Bandung
# 669                          Bandung
# 670        Cisaranten Wetan, Bandung
# 678                          Bandung
# 694               Cipaganti, Bandung
# 739                 Pasteur, Bandung
# 824              Parongpong, Bandung
# 855               Margahayu, Bandung
# 933             Ciumbuleuit, Bandung
# 1028             Parongpong, Bandung
# 1059                  Regol, Bandung
# 1062          Gatot Subroto, Bandung
# 1091               Surapati, Bandung
# 1098                   Dago, Bandung
# 1192                         Bandung
# 1252                Pasteur, Bandung
# 1290             Parongpong, Bandung
# 1298                   Riau, Bandung
# 1326                Cidadap, Bandung
# 1347                   Riau, Bandung
# 1386                         Bandung
# 1404                Pasteur, Bandung
# 1417                         Bandung
# 1434                         Bandung
# 1450                         Bandung
#
#                                               deskripsi  kamar  luas_bangunan
# 38    Dijual Rumah Kost atau Kontrakan Bangunan Baru...     13            450  \
# 118   Dijual : Rumah Mekar Wangi - 3.2 M (nego)  SHM...      9            300
# 134   Rumah di Jual di Setiabudi Regency, Bandung. R...      8            650
# 162   Dijual Kos kosan di Bandung SHM.  Luas Tanah :...     23           1085
# 218   Prime Location Sayap Dago @Sultan Agung   Repo...     12            400
# 220   Rumah di Setiabudi, Cipaganti Appraisal 2017 4...      8           1500
# 256   Jual Rumah Kost Dekat Samsat Soekarno Hatta By...     15            185
# 282   Readystock Rumah Mewah CLuster dkt UPI Setiabu...      8            350
# 305   Rumah Kost Bangunan Baru, Lokasi Strategis dek...     11            250
# 313   Sayap Buahbatu Kota Bandung MURAH !! Harga pen...     10            300
# 330   Rumah semi minimalis terletak di Sarikaso Sari...      9            400
# 338   Dijual cepat rumah sangat murah di bawah harga...      8            400
# 359   Jual Rumah 2 Lantai Komplek Pilar Biru  Cibiru...      8            320
# 390   dijual kost2an syp pjjran lt175 lb320 ,18 kt,8...     18            320
# 399   Spesifikasi Luas Tanah  : 200 Luas Bangunan : ...      9            300
# 404   Dijual cepat rumah second hand  4 lantai kokoh...     15            196
# 440   Dijual Rumah Lt. 905m Lb. 213m  Fasilitas : (R...      8            213
# 443   Dijual Rumah Kost Komplek Muara Bandung Dekat ...     24            600
# 495   KOST2SAN : ...di Jatinangor....... Surat2 : .....     18            750
# 507   Rumah terawat di cipedes selatan, Lokasi strat...      8            323
# 567   lokasi strategis area campus jatinangor. banya...     37            600
# 603   Hotel Melati sangat bagus terawat dan siap hun...     11            175
# 638   Dijual cepat Tanah Ngantong Bonus Bangunan di ...     37            745
# 669   Rumah siap huni dengan lingkungan yang nyaman ...      8            350
# 670   Dijual rumah besar mewah lokasi strategis di k...      9            350
# 678   Rumah 2 lantai (plus tempat torn+jemuran), 8KT...      8            224
# 694   Bismiilah, dijuall rumah terawat pusat kota ka...      8            500
# 739   TERLETAK SANGAT STRATEGIS, PUSAT KOTA, DEKAT T...     16            350
# 824   Rumah Readystock Mewah CLuster di Lembang deka...      8            350
# 855   SPEK:  LB 335 M2 LT 188 M2 KT 8 KM 3 CARPORT 1...      8            335
# 933   Rumah kost super premium di Ciumbuleuit,Bandun...     47           1850
# 1028  Dijual rumah mewah dan asri dengan udara yg se...      9            400
# 1059  Dijual Rumah Sayap BKR BandungLuas Tanah 220 m...      8            224
# 1062  Luas Tanah 624 m²Luas Bangunan 230 m²3 LantaiL...      9            230
# 1091  dijual murah cepat kost di jalan suci kota Ban...      8            200
# 1098  lokasi strategis area dago. kawasan elit exclu...     10           1200
# 1192  Jual sebidang tanah dengan bonus tiga rumah ba...     10            186
# 1252  Rumah kost dan rumah tinggal terawat di Sayap ...     15            200
# 1290  Jual Cepat Muraah Villa di Kawasan Wisata Lemb...      8           1500
# 1298  Rumah Mewah Supratman Sayap Riau  LT : 420m2 L...      8            510
# 1326  spesifikasi sebagai berikut : - Siap PAKAI - L...     11            200
# 1347  DijualRumah Mainroad Sayap RiauCocok utk rumah...     15            500
# 1386  Dijual Cepat Rumah Di Buahbatu Jl. Sekarmanis ...      8            324
# 1404  SHM 421/431 LEBAR MUKA 19 KT 8+2 KM 5+1 GARASI...      8            431
# 1417  Rumah Kosan Aktif, Spek :- Lokasi stategis per...      9            240
# 1434  Rumah di Jl. Cipaku indah , jarang adaAkses lo...      9            500
# 1450  Rumah di Jl. Cipaku indah , jarang adaAkses lo...      9            500
#
#       luas_lahan        harga
# 38           421   2300000000
# 118          215   3200000000
# 134          320   4600000000
# 162          385   9500000000
# 218          642  21000000000
# 220         1170  33000000000
# 256          200   2000000000
# 282          276   3250000000
# 305          420   4199999000
# 313          477   3500000000
# 330          375   3250000000
# 338          420   9900000000
# 359          252   2250000000
# 390          175   1850000000
# 399          200   1300000000
# 404          196   3500000000
# 440          905   7200000000
# 443          300   3750000000
# 495          164   5500000000
# 507          250   3250000000
# 567          494   4500000000
# 603          200   3200000000
# 638         1540  43000000000
# 669          465   3200000000
# 670          202   1100000000
# 678          178   1700000000
# 694          765  22500000000
# 739          210   6900000000
# 824          276   4075000000
# 855          188    900000000
# 933          970  17000000000
# 1028         360   2800000000
# 1059         220   4000000000
# 1062         624  14000000000
# 1091         110    850000000
# 1098        4015  57000000000
# 1192         540   1400000000
# 1252         285   2750000000
# 1290       15000  16000000000
# 1298         420  13000000000
# 1326         392   2600000000
# 1347         640  19500000000
# 1386         524   9516200000
# 1404         421   5500000000
# 1417         120   1700000000
# 1434         331   3500000000
# 1450         331   3500000000

# %% [markdown]
# *Visualisasi Outlier Kamar*

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
sns.boxplot(data=df, y='kamar', color='green')
plt.title('Boxplot Jumlah Kamar')
plt.ylabel('Jumlah')
plt.show()

# %% [markdown]
# **DATA PREPARATION**

# %% [markdown]
# *DATA CLEANING*

# %%
jumlah_duplikat = df.duplicated().sum()
print(f'Jumlah data duplikat: {jumlah_duplikat}')
# Out:
# Jumlah data duplikat: 0

# %% [markdown]
# *DATA NULL*

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ID             1470 non-null   int64
#  1   judul          1470 non-null   object
#  2   alamat         1470 non-null   object
#  3   deskripsi      1468 non-null   object
#  4   kamar          1470 non-null   int64
#  5   luas_bangunan  1470 non-null   int64
#  6   luas_lahan     1470 non-null   int64
#  7   harga          1470 non-null   int64
# dtypes: int64(5), object(3)
# memory usage: 92.0+ KB

# %%
missing_value = df.isnull().sum()
print(missing_value)
# Out:
# ID               0
# judul            0
# alamat           0
# deskripsi        2
# kamar            0
# luas_bangunan    0
# luas_lahan       0
# harga            0
# dtype: int64

# %%
df.columns = ['ID', 'judul', 'alamat', 'deskripsi', 'kamar', 'luas_bangunan', 'luas_lahan', 'harga']
df.to_excel('data_rumah_updated.xlsx', index=False)

# %%
print(df.columns)
# Out:
# Index(['ID', 'judul', 'alamat', 'deskripsi', 'kamar', 'luas_bangunan',
#        'luas_lahan', 'harga'],
#       dtype='object')

# %% [markdown]
# *Mengoreksi nilai yang tidak valid*

# %%
kamar_kosong = df[df['kamar'] < 1]
luas_bangunan_kosong = df[df['luas_bangunan'] < 20]
luas_lahan_kosong = df[df['luas_lahan'] < 20]
negatif_harga = df[df['harga'] < 0]

print("Jumlah data dengan kamar kosong:", len(kamar_kosong))
print("Jumlah data dengan luas bangunan tidak valid:", len(luas_bangunan_kosong))
print("Jumlah data dengan luas lahan tidak valid:", len(luas_lahan_kosong))
print("Jumlah data dengan harga negatif:", len(negatif_harga))
# Out:
# Jumlah data dengan kamar kosong: 8
# Jumlah data dengan luas bangunan tidak valid: 4
# Jumlah data dengan luas lahan tidak valid: 3
# Jumlah data dengan harga negatif: 0

# %%
df = df[df['kamar'] >= 1]
df = df[df['luas_bangunan'] >= 20]
df = df[df['luas_lahan'] >= 20]
print("Jumlah data setelah penghapusan:", len(df))
# Out:
# Jumlah data setelah penghapusan: 1456

# %% [markdown]
# *Hapus Data Outlier*

# %%
import pandas as pd

Q1 = df['kamar'].quantile(0.25)  
Q3 = df['kamar'].quantile(0.75) 
IQR = Q3 - Q1                    

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
outliers = df[(df['kamar'] < lower_bound) | (df['kamar'] > upper_bound)]

print("Jumlah outlier pada kolom kamar:", len(outliers))
print("Batas bawah:", lower_bound)
print("Batas atas:", upper_bound)
print("\nOutlier pada kolom kamar:")
print(outliers)
# Out:
# Jumlah outlier pada kolom kamar: 47
# Batas bawah: -1.0
# Batas atas: 7.0
#
# Outlier pada kolom kamar:
#         ID                                              judul
# 38      38  Rumah Kost Bangunan Baru + Kios Turun Harga di...  \
# 118    118  Jual murah rumah minimalis, Mekar Wangi, Bandu...
# 134    134  JUAL Rumah SEHAT  2 Lantai di SETIABUDI REGENC...
# 162    162  Dijual Kos Kosan "Sweet Home" di Bandung Lokas...
# 218    218           Rumah di sayap dago sultan agung bandung
# 220    220  For Sale Rumah di Setiabudi, Cipaganti Apprais...
# 256    256  Rumah Kost Dekat Samsat Soekarno Hatta Bypass ...
# 282    282  Readystock Rumah Nuansa Islami Lembang Bandung...
# 305    305  Rumah Kost Siap Pakai di Dekat STT Telkom Tol ...
# 313    313  Rumah dijual murah di Buahbatu Bandung, luas b...
# 330    330  Rumah Semi minimalis di Sarikaso, Sarijadi, co...
# 338    338  Rumah hot istimewa di jl Taman Pramuka kota Ba...
# 359    359               Jual Rumah Pilar Biru  Bandung timur
# 390    390          Dijual kost2an syp pjjran Bandung - Henny
# 399    399   Dijual Rumah di Komplek Logam, buah batu Bandung
# 404    404  JUAL CEPAT RUMAH SECOND MULTIFUNGSI LOKASI STR...
# 440    440           DIJUAL RUMAH BERHALAMAN LUAS DI CIBEREUM
# 443    443  Dijual Rumah Kost Komplek Muara Bandung Dekat ...
# 495    495                          Kost-Kostan di Jatinangor
# 507    507  Rumah di cipedes selatan dekat hotel aston LM ...
# 567    567  Kost Aktif Jatinangor Bandung Dekat Kampus, Fu...
# 603    603  Hotel melati aktif di turangga lengkong bagus ...
# 638    638  Tanah Ngantong Bonus Bangunan di Sayap Dago De...
# 669    669  Rumah di Lembah Permai Hanjuang, Lingkungan as...
# 670    670  Rumah Besar Mewah Di Jual Murah Di Cisaranten ...
# 678    678                 Rumah Strategis Nyaman - Bumi Asri
# 694    694                         Rumah Terawat Di Cipaganti
# 739    739  Dijual Rumah Area Cipaganti Bandung Lokasi Str...
# 824    824  Rumah Mewah Konsep Syariah plus Furniture di L...
# 855    855                       RUMAH JL SADANG SARI BANDUNG
# 933    933  Rumah kost luxuary, super premium di Ciumbuleu...
# 1028  1028                     Rumah mewah dan udaranya alami
# 1059  1059                     Dijual Rumah Sayap BKR Bandung
# 1062  1062  Dijual Rumah Hitung Tanah Mainroad Gatot Subro...
# 1091  1091  Murah !! kost aktif untuk invest dekat kampus ...
# 1098  1098  Dago - Komplek Elite, Bangunan Mevvah, Harga D...
# 1192  1192  Jual tanah 540 M2 hanya 1,4 Milyar bonus 4 rum...
# 1252  1252  Rumah Kost Terawat di Sukaresik, Sayap Babakan...
# 1290  1290     Jual Cepat Muraah Villa Lembang Cikole Bandung
# 1298  1298                   Rumah Mewah Supratman Sayap Riau
# 1326  1326  JUAL RUMAH 2LANTAI DI JL BUDI INDAH LEDENG CID...
# 1347  1347  Dijual Rumah Mainroad Sayap Riau. Cocok Untuk ...
# 1386  1386  Dijual Rumah Mewah Di Pusat Kota  Buahbatu Hal...
# 1404  1404  Dijual Rumah Dekat Istana Plaza Pajajaran Bandung
# 1417  1417  Rumah Kosan Aktif Lokasi Stategis Perumahan Cl...
# 1434  1434  Rumah Mewah Siap Huni Cipaku Indah, Kotamadya ...
# 1450  1450  Rumah Mewah Siap Huni Cipaku Indah, Kotamadya ...
#
#                               alamat
# 38                Sukamenak, Bandung  \
# 118              Mekarwangi, Bandung
# 134               Setiabudi, Bandung
# 162             Dayeuhkolot, Bandung
# 218                    Dago, Bandung
# 220               Setiabudi, Bandung
# 256                Buahbatu, Bandung
# 282                 Lembang, Bandung
# 305             Bojongsoang, Bandung
# 313                Buahbatu, Bandung
# 330                          Bandung
# 338           Bandung Wetan, Bandung
# 359                  Cibiru, Bandung
# 390               Pajajaran, Bandung
# 399   Buahbatu (Margacinta), Bandung
# 404                    Kopo, Bandung
# 440                Paledang, Bandung
# 443         Bojongloa Kidul, Bandung
# 495              Jatinangor, Bandung
# 507                 Pasteur, Bandung
# 567              Jatinangor, Bandung
# 603                Turangga, Bandung
# 638                          Bandung
# 669                          Bandung
# 670        Cisaranten Wetan, Bandung
# 678                          Bandung
# 694               Cipaganti, Bandung
# 739                 Pasteur, Bandung
# 824              Parongpong, Bandung
# 855               Margahayu, Bandung
# 933             Ciumbuleuit, Bandung
# 1028             Parongpong, Bandung
# 1059                  Regol, Bandung
# 1062          Gatot Subroto, Bandung
# 1091               Surapati, Bandung
# 1098                   Dago, Bandung
# 1192                         Bandung
# 1252                Pasteur, Bandung
# 1290             Parongpong, Bandung
# 1298                   Riau, Bandung
# 1326                Cidadap, Bandung
# 1347                   Riau, Bandung
# 1386                         Bandung
# 1404                Pasteur, Bandung
# 1417                         Bandung
# 1434                         Bandung
# 1450                         Bandung
#
#                                               deskripsi  kamar  luas_bangunan
# 38    Dijual Rumah Kost atau Kontrakan Bangunan Baru...     13            450  \
# 118   Dijual : Rumah Mekar Wangi - 3.2 M (nego)  SHM...      9            300
# 134   Rumah di Jual di Setiabudi Regency, Bandung. R...      8            650
# 162   Dijual Kos kosan di Bandung SHM.  Luas Tanah :...     23           1085
# 218   Prime Location Sayap Dago @Sultan Agung   Repo...     12            400
# 220   Rumah di Setiabudi, Cipaganti Appraisal 2017 4...      8           1500
# 256   Jual Rumah Kost Dekat Samsat Soekarno Hatta By...     15            185
# 282   Readystock Rumah Mewah CLuster dkt UPI Setiabu...      8            350
# 305   Rumah Kost Bangunan Baru, Lokasi Strategis dek...     11            250
# 313   Sayap Buahbatu Kota Bandung MURAH !! Harga pen...     10            300
# 330   Rumah semi minimalis terletak di Sarikaso Sari...      9            400
# 338   Dijual cepat rumah sangat murah di bawah harga...      8            400
# 359   Jual Rumah 2 Lantai Komplek Pilar Biru  Cibiru...      8            320
# 390   dijual kost2an syp pjjran lt175 lb320 ,18 kt,8...     18            320
# 399   Spesifikasi Luas Tanah  : 200 Luas Bangunan : ...      9            300
# 404   Dijual cepat rumah second hand  4 lantai kokoh...     15            196
# 440   Dijual Rumah Lt. 905m Lb. 213m  Fasilitas : (R...      8            213
# 443   Dijual Rumah Kost Komplek Muara Bandung Dekat ...     24            600
# 495   KOST2SAN : ...di Jatinangor....... Surat2 : .....     18            750
# 507   Rumah terawat di cipedes selatan, Lokasi strat...      8            323
# 567   lokasi strategis area campus jatinangor. banya...     37            600
# 603   Hotel Melati sangat bagus terawat dan siap hun...     11            175
# 638   Dijual cepat Tanah Ngantong Bonus Bangunan di ...     37            745
# 669   Rumah siap huni dengan lingkungan yang nyaman ...      8            350
# 670   Dijual rumah besar mewah lokasi strategis di k...      9            350
# 678   Rumah 2 lantai (plus tempat torn+jemuran), 8KT...      8            224
# 694   Bismiilah, dijuall rumah terawat pusat kota ka...      8            500
# 739   TERLETAK SANGAT STRATEGIS, PUSAT KOTA, DEKAT T...     16            350
# 824   Rumah Readystock Mewah CLuster di Lembang deka...      8            350
# 855   SPEK:  LB 335 M2 LT 188 M2 KT 8 KM 3 CARPORT 1...      8            335
# 933   Rumah kost super premium di Ciumbuleuit,Bandun...     47           1850
# 1028  Dijual rumah mewah dan asri dengan udara yg se...      9            400
# 1059  Dijual Rumah Sayap BKR BandungLuas Tanah 220 m...      8            224
# 1062  Luas Tanah 624 m²Luas Bangunan 230 m²3 LantaiL...      9            230
# 1091  dijual murah cepat kost di jalan suci kota Ban...      8            200
# 1098  lokasi strategis area dago. kawasan elit exclu...     10           1200
# 1192  Jual sebidang tanah dengan bonus tiga rumah ba...     10            186
# 1252  Rumah kost dan rumah tinggal terawat di Sayap ...     15            200
# 1290  Jual Cepat Muraah Villa di Kawasan Wisata Lemb...      8           1500
# 1298  Rumah Mewah Supratman Sayap Riau  LT : 420m2 L...      8            510
# 1326  spesifikasi sebagai berikut : - Siap PAKAI - L...     11            200
# 1347  DijualRumah Mainroad Sayap RiauCocok utk rumah...     15            500
# 1386  Dijual Cepat Rumah Di Buahbatu Jl. Sekarmanis ...      8            324
# 1404  SHM 421/431 LEBAR MUKA 19 KT 8+2 KM 5+1 GARASI...      8            431
# 1417  Rumah Kosan Aktif, Spek :- Lokasi stategis per...      9            240
# 1434  Rumah di Jl. Cipaku indah , jarang adaAkses lo...      9            500
# 1450  Rumah di Jl. Cipaku indah , jarang adaAkses lo...      9            500
#
#       luas_lahan        harga
# 38           421   2300000000
# 118          215   3200000000
# 134          320   4600000000
# 162          385   9500000000
# 218          642  21000000000
# 220         1170  33000000000
# 256          200   2000000000
# 282          276   3250000000
# 305          420   4199999000
# 313          477   3500000000
# 330          375   3250000000
# 338          420   9900000000
# 359          252   2250000000
# 390          175   1850000000
# 399          200   1300000000
# 404          196   3500000000
# 440          905   7200000000
# 443          300   3750000000
# 495          164   5500000000
# 507          250   3250000000
# 567          494   4500000000
# 603          200   3200000000
# 638         1540  43000000000
# 669          465   3200000000
# 670          202   1100000000
# 678          178   1700000000
# 694          765  22500000000
# 739          210   6900000000
# 824          276   4075000000
# 855          188    900000000
# 933          970  17000000000
# 1028         360   2800000000
# 1059         220   4000000000
# 1062         624  14000000000
# 1091         110    850000000
# 1098        4015  57000000000
# 1192         540   1400000000
# 1252         285   2750000000
# 1290       15000  16000000000
# 1298         420  13000000000
# 1326         392   2600000000
# 1347         640  19500000000
# 1386         524   9516200000
# 1404         421   5500000000
# 1417         120   1700000000
# 1434         331   3500000000
# 1450         331   3500000000

# %%
df_cleaned = df[(df['kamar'] >= lower_bound) & (df['kamar'] <= upper_bound)]

print("Jumlah data sebelum penghapusan outlier:", len(df))
print("Jumlah data setelah penghapusan outlier:", len(df_cleaned))
# Out:
# Jumlah data sebelum penghapusan outlier: 1456
# Jumlah data setelah penghapusan outlier: 1409

# %% [markdown]
# *Independent Component Analysis (ICA) kolom alamat, hapus keterangan Bandung*

# %%
import pandas as pd
from sklearn.decomposition import FastICA

bandung_only_count = df_cleaned[df_cleaned['alamat'].str.strip() == 'Bandung'].shape[0]
print(f"Jumlah baris yang hanya berisi 'Bandung': {bandung_only_count}")
# Out:
# Jumlah baris yang hanya berisi 'Bandung': 239

# %%
df_cleaned = df_cleaned[df_cleaned['alamat'].str.strip() != 'Bandung']

# %%
df_cleaned.shape
# Out:
# (1170, 8)

# %%
df_cleaned['alamat'] = df_cleaned['alamat'].str.replace(r',\s*Bandung$', '', regex=True).str.strip()

# %%
print(df_cleaned.head())
# Out:
#    ID                                              judul         alamat
# 0   0                      Promo Rumah Mewah Akhir Tahun       Antapani  \
# 1   1  Rumah modern Readystock di bandung raya cimahi...  Bandung Wetan
# 2   2  Dijual rumah 300 jutaan jalan lebar dekat Ikea...     Padalarang
# 4   4  Rumah Strategis Siap Huni di dekat Tol Cileuny...   Cibiru Hilir
# 5   5  Rumah Bandung Luas type 60/60 Promo Awal Tahun...      Setiabudi
#
#                                            deskripsi  kamar  luas_bangunan
# 0  Promo akhir tahun !! Hanya 500 jt-an + FREE SH...      3             75  \
# 1  Rumah Baru modern 2 LT di Sayap Kota Cimahi de...      3             70
# 2  *Jadilah konsumen CERDAS !* *Tips singkat sebe...      2             36
# 4  Hunian Nyaman di Cibiru, Cileunyi, Bandung Tim...      2             90
# 5  WINTERGREEN DELUXE\nHargta Promo 557jt\nHarga ...      2             60
#
#    luas_lahan      harga
# 0          84  590000000
# 1          71  700000000
# 2          72  386000000
# 4         114  397500000
# 5          60  557000000

# %% [markdown]
# *Data Reduction*

# %% [markdown]
# Clustering Berdasarkan Harga

# %%
import pandas as pd

bins = [0, 5e8, 1e9, float('inf')]  # 0-500 juta, 500 juta-1 milyar, 1 milyar ke atas
labels = ['lower', 'middle', 'upper']

df_cleaned['kategori_harga'] = pd.cut(df_cleaned['harga'], bins=bins, labels=labels, right=False)
print(df_cleaned)
# Out:
#         ID                                              judul          alamat
# 0        0                      Promo Rumah Mewah Akhir Tahun        Antapani  \
# 1        1  Rumah modern Readystock di bandung raya cimahi...   Bandung Wetan
# 2        2  Dijual rumah 300 jutaan jalan lebar dekat Ikea...      Padalarang
# 4        4  Rumah Strategis Siap Huni di dekat Tol Cileuny...    Cibiru Hilir
# 5        5  Rumah Bandung Luas type 60/60 Promo Awal Tahun...       Setiabudi
# ...    ...                                                ...             ...
# 1464  1464          Rumah Murah Dijual di Gegerkalong Bandung     Gegerkalong
# 1465  1465                                Rumah Lama Turangga        Turangga
# 1467  1467  Rumah Minimalis Siap Huni Sangat Murah Di Pinu...  Soekarno Hatta
# 1468  1468  Dijual Cepat Rumah Strategis di Komplek Batura...       Rancasari
# 1469  1469  Rumah turangga bagus siap huni turun harga dra...        Turangga
#
#                                               deskripsi  kamar  luas_bangunan
# 0     Promo akhir tahun !! Hanya 500 jt-an + FREE SH...      3             75  \
# 1     Rumah Baru modern 2 LT di Sayap Kota Cimahi de...      3             70
# 2     *Jadilah konsumen CERDAS !* *Tips singkat sebe...      2             36
# 4     Hunian Nyaman di Cibiru, Cileunyi, Bandung Tim...      2             90
# 5     WINTERGREEN DELUXE\nHargta Promo 557jt\nHarga ...      2             60
# ...                                                 ...    ...            ...
# 1464  Dijual : Rumah tanah luas di  Cluster Elite di...      5            380
# 1465  Di jual rumah lama turangga\nLuas tanah : 240 ...      6            280
# 1467  Turun HargaHarga Awal 675 sekarang jadi 572 ne...      2             65
# 1468  Dijual Cepat Rumah di Komplek Batu Raden dekat...      6            160
# 1469  Turun Harga drastis CAKEP BOSQUE.. Area Turang...      5            240
#
#       luas_lahan       harga kategori_harga
# 0             84   590000000         middle
# 1             71   700000000         middle
# 2             72   386000000          lower
# 4            114   397500000          lower
# 5             60   557000000         middle
# ...          ...         ...            ...
# 1464         564  4900000000          upper
# 1465         240  2800000000          upper
# 1467          72   572000000         middle
# 1468         318  2300000000          upper
# 1469         188  2400000000          upper
#
# [1170 rows x 9 columns]

# %%
df_cleaned.head()
# Out:
#    ID                                              judul         alamat
# 0   0                      Promo Rumah Mewah Akhir Tahun       Antapani  \
# 1   1  Rumah modern Readystock di bandung raya cimahi...  Bandung Wetan
# 2   2  Dijual rumah 300 jutaan jalan lebar dekat Ikea...     Padalarang
# 4   4  Rumah Strategis Siap Huni di dekat Tol Cileuny...   Cibiru Hilir
# 5   5  Rumah Bandung Luas type 60/60 Promo Awal Tahun...      Setiabudi
#
#                                            deskripsi  kamar  luas_bangunan
# 0  Promo akhir tahun !! Hanya 500 jt-an + FREE SH...      3             75  \
# 1  Rumah Baru modern 2 LT di Sayap Kota Cimahi de...      3             70
# 2  *Jadilah konsumen CERDAS !* *Tips singkat sebe...      2             36
# 4  Hunian Nyaman di Cibiru, Cileunyi, Bandung Tim...      2             90
# 5  WINTERGREEN DELUXE\nHargta Promo 557jt\nHarga ...      2             60
#
#    luas_lahan      harga kategori_harga
# 0          84  590000000         middle
# 1          71  700000000         middle
# 2          72  386000000          lower
# 4         114  397500000          lower
# 5          60  557000000         middle

# %%
jumlah_per_kategori = df_cleaned['kategori_harga'].value_counts()
print(jumlah_per_kategori)
# Out:
# kategori_harga
# upper     686
# middle    275
# lower     209
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

colors = {'lower': 'blue', 'middle': 'orange', 'upper': 'green'}

plt.figure(figsize=(10, 6))
for kategori, warna in colors.items():
    subset = df_cleaned[df_cleaned['kategori_harga'] == kategori]
    plt.scatter(subset['harga'], subset['luas_bangunan'], label=kategori, color=warna)

plt.title('Hasil Clustering Harga Rumah', fontsize=14)
plt.xlabel('Harga', fontsize=12)
plt.ylabel('Luas Bangunan', fontsize=12)
plt.legend(title='Kategori Harga')
plt.tight_layout()
plt.show()

# %%
# Mengambil sampling 100 data untuk setiap kategori harga 
sampling_per_category = df_cleaned.groupby('kategori_harga').sample(n=100, random_state=42) 
print(sampling_per_category)
# Out:
#         ID                                              judul         alamat
# 58      58  Rumah harga 500 jutaan di Ciwastra.Bangunan mewah       Ciwastra  \
# 889    889  Hunian Termurah 2lantai Bonus Pagar Lokasi Cil...       Cileunyi
# 198    198           RUMAH CLUSTER DP 0% DI RANCAEKEK BANDUNG      Rancaekek
# 1272  1272  Cicilan 2,1JT Proses dibantu sampai ACC Lokasi...        Nanjung
# 132    132  Harga Bersahabat Rumah Siap Huni Type 40/55 FU...    Bojongsoang
# ...    ...                                                ...            ...
# 903    903  JUAL RUMAH BISA UNTUK HOMEINDUSTRI TAMAN HOLIS...  Bandung Kulon
# 842    842  Dijual Rumah Baru Singgasana Pradana,Murah,Sia...     Mekarwangi
# 581    581  Jual rumah minimalis taman holis indah full fu...     Cigondewah
# 965    965              Rumah Siap Huni Strategis Batununggal    Batununggal
# 472    472       Rumah di Singgasana Pradana Elite Strategis!     Mekarwangi
#
#                                               deskripsi  kamar  luas_bangunan
# 58    BENTANG ARTHA RESIDENCE    Perumahan bergaya e...      2             40  \
# 889   Rumah Baru 2 Lantai View Bandung Bebas Banjir ...      3             50
# 198   Baru ada rumah Cluster di pinggir jalan Raya t...      2             29
# 1272  Cicilan 2,1JT Proses dibantu sampai ACC Lokasi...      2             30
# 132   Rumah Siap Huni  Harga 225juta boleh nego yaa ...      2             40
# ...                                                 ...    ...            ...
# 903   Jangan Salah Beli! Jangan Salah Pilih juga. SU...      4            350
# 842   Dijual Rumah Baru Singgasana Pradana,Murah,Sia...      5            190
# 581   Jual rumah minimalis full furnish  LT 120 m  L...      3            155
# 965   Dijual Cepat Rumah Siap Huni Strategis Batunun...      5            330
# 472   Singgasana Pradana Rumah Kondisi Baik Jarang A...      4            110
#
#       luas_lahan       harga kategori_harga
# 58            60   477500000          lower
# 889           60   428000000          lower
# 198           60   297000000          lower
# 1272          66   424990000          lower
# 132           55   225000000          lower
# ...          ...         ...            ...
# 903          270  2950000000          upper
# 842          135  2950000000          upper
# 581          120  1350000000          upper
# 965          334  5500000000          upper
# 472          145  2400000000          upper
#
# [300 rows x 9 columns]

# %% [markdown]
# **Detecting missing values after Clustering**

# %% [markdown]
# *Mengecek Nilai Null*

# %%
missing_value = df_cleaned.isnull().sum()
print(missing_value)
# Out:
# ID                0
# judul             0
# alamat            0
# deskripsi         2
# kamar             0
# luas_bangunan     0
# luas_lahan        0
# harga             0
# kategori_harga    0
# dtype: int64

# %%
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1170 entries, 0 to 1469
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ID              1170 non-null   int64
#  1   judul           1170 non-null   object
#  2   alamat          1170 non-null   object
#  3   deskripsi       1168 non-null   object
#  4   kamar           1170 non-null   int64
#  5   luas_bangunan   1170 non-null   int64
#  6   luas_lahan      1170 non-null   int64
#  7   harga           1170 non-null   int64
#  8   kategori_harga  1170 non-null   category
# dtypes: category(1), int64(5), object(3)
# memory usage: 83.5+ KB

# %% [markdown]
# **Data Transformation**

# %% [markdown]
# **Agregasi**

# %% [markdown]
# *Menghitung Rata-Rata Harga rumah*

# %%
rata_rata_per_kategori = df_cleaned.groupby('kategori_harga')['harga'].mean()
print("Rata-rata harga rumah per kategori:")
for kategori, rata_rata in rata_rata_per_kategori.items():
    print(f"{kategori}: Rp {rata_rata:,.0f}")
# Out:
# Rata-rata harga rumah per kategori:
# lower: Rp 318,670,815
# middle: Rp 721,308,192
# upper: Rp 3,512,424,501

# %% [markdown]
# # Data Modelling

# %% [markdown]
# ### Labelling Data

# %%
df_cleaned.describe()
# Out:
#                 ID        kamar  luas_bangunan   luas_lahan         harga
# count  1170.000000  1170.000000    1170.000000  1170.000000  1.170000e+03
# mean    693.838462     3.312821     159.393162   184.406838  2.285885e+09
# std     421.050105     1.241397     145.976161   312.428242  3.614978e+09
# min       0.000000     1.000000      21.000000    30.000000  6.500000e+07
# 25%     319.250000     2.000000      60.000000    74.000000  6.250000e+08
# 50%     678.000000     3.000000     110.500000   115.500000  1.250000e+09
# 75%    1042.500000     4.000000     200.000000   195.250000  2.750000e+09
# max    1469.000000     7.000000    1400.000000  8000.000000  4.300000e+10

# %%
x = df_cleaned.drop(columns=['ID','judul','alamat','deskripsi','harga','kategori_harga'])
y = df_cleaned['harga']

print("Variabel Independen (X): ")
print(x.head())
print("Variabel Dependen (Y): ")
print(y.head())
# Out:
# Variabel Independen (X):
#    kamar  luas_bangunan  luas_lahan
# 0      3             75          84
# 1      3             70          71
# 2      2             36          72
# 4      2             90         114
# 5      2             60          60
# Variabel Dependen (Y):
# 0    590000000
# 1    700000000
# 2    386000000
# 4    397500000
# 5    557000000
# Name: harga, dtype: int64

# %% [markdown]
# ### Split Dataset

# %% [markdown]
# Memisahkan data uji dan data latih sesuai kebutuhan model

# %% [markdown]
# Split dataset untuk training dan testing, size data uji sebanyak 20%

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %% [markdown]
# ### Build Model

# %% [markdown]
# Melatih model Linear Regression

# %%
from sklearn.linear_model import LinearRegression   

linear_model = LinearRegression()
linear_model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# Membuat prediksi dari model yang sudah dilatih, buat prediksi pada data latih maupun data uji (X_train, X_test)

# %%
y_pred = linear_model.predict(X_test)

# %% [markdown]
# Menampilkan rata-rata kuadrat kesalahan antara nilai prediksi dan nilai aktual

# %%
from sklearn.metrics import mean_squared_error, r2_score

mse = mean_squared_error(y_test, y_pred)
print(f"Mean Squarred Erro: {mse}")
# Out:
# Mean Squarred Erro: 1.0740434726634764e+19

# %% [markdown]
# Menampilkan  proporsi varians dalam variabel dependen yang dapat dijelaskan oleh model

# %%
r2 = r2_score(y_test, y_pred)
print(f"R-squared: {r2}")
# Out:
# R-squared: 0.4281023139075145

# %%
variables = ["kamar", "luas_lahan", "luas_bangunan"]
for var in variables:
    plt.figure(figsize=(10, 6))
    sns.regplot(x=df_cleaned[var], y=df_cleaned["harga"], line_kws={"color": "red"})
    plt.title(f"Jumlah {var} vs Harga")
    plt.xlabel(var)
    plt.ylabel("harga")
    plt.show()

# %% [markdown]
# ### Implementasi K-Medoids

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn_extra.cluster import KMedoids
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Fitur untuk clustering
features = df_cleaned[['harga', 'luas_bangunan', 'luas_lahan']]

# Standardisasi data untuk mengurangi pengaruh skala
scaler = StandardScaler()
features_scaled = scaler.fit_transform(features)

# %% [markdown]
# **Inisialisasi dan Latih K-Medoid Clustering**

# %%
# Inisialisasi K-Medoids
kmedoids = KMedoids(n_clusters=3, random_state=42)

# Latih model
kmedoids.fit(features_scaled)

# Tambahkan label cluster ke dataset
df_cleaned['cluster'] = kmedoids.labels_

# %% [markdown]
# ***Visualisasi Hasil Clustering***
#
# Visualisasi untuk melihat bagaimana properti dikelompokkan berdasarkan fitur

# %%
# Mapping cluster numbers to categories
cluster_mapping = {0: 'lower', 1: 'middle', 2: 'upper'}
df_cleaned['cluster'] = df_cleaned['cluster'].map(cluster_mapping)

# Visualisasi dengan scatter plot
plt.figure(figsize=(10, 6))
sns.scatterplot(
    x=features_scaled[:, 0],  # harga (scaled)
    y=features_scaled[:, 1],  # luas bangunan (scaled)
    hue=df_cleaned['cluster'],  # menggunakan kategori
    palette='viridis'
)
plt.title("K-Medoids Clustering")
plt.xlabel("Harga (Scaled)")
plt.ylabel("Luas Bangunan (Scaled)")
plt.legend(title="Cluster")
plt.show()

# %% [markdown]
# ***Optimal Number of Clusters***
#
#
# Untuk memastikan jumlah cluster optimal, gunakan metode seperti Elbow Method:

# %%
from sklearn.metrics import silhouette_score

scores = []
for k in range(2, 10):
    model = KMedoids(n_clusters=k, random_state=42)
    model.fit(features_scaled)
    scores.append(silhouette_score(features_scaled, model.labels_))

# Plot silhouette scores
plt.plot(range(2, 10), scores, marker='o')
plt.title("Silhouette Scores for K-Medoid Clustering")
plt.xlabel("Number of Clusters")
plt.ylabel("Silhouette Score")
plt.show()
# Out:
# c:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn_extra\cluster\_k_medoids.py:329: UserWarning: Cluster 3 is empty! self.labels_[self.medoid_indices_[3]] may not be labeled with its corresponding cluster (3).
#   warnings.warn(
# c:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn_extra\cluster\_k_medoids.py:329: UserWarning: Cluster 3 is empty! self.labels_[self.medoid_indices_[3]] may not be labeled with its corresponding cluster (3).
#   warnings.warn(
# c:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn_extra\cluster\_k_medoids.py:329: UserWarning: Cluster 3 is empty! self.labels_[self.medoid_indices_[3]] may not be labeled with its corresponding cluster (3).
#   warnings.warn(
# c:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn_extra\cluster\_k_medoids.py:329: UserWarning: Cluster 3 is empty! self.labels_[self.medoid_indices_[3]] may not be labeled with its corresponding cluster (3).
#   warnings.warn(
# c:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn_extra\cluster\_k_medoids.py:329: UserWarning: Cluster 6 is empty! self.labels_[self.medoid_indices_[6]] may not be labeled with its corresponding cluster (6).
#   warnings.warn(
# c:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn_extra\cluster\_k_medoids.py:329: UserWarning: Cluster 3 is empty! self.labels_[self.medoid_indices_[3]] may not be labeled with its corresponding cluster (3).
#   warnings.warn(
# c:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn_extra\cluster\_k_medoids.py:329: UserWarning: Cluster 6 is empty! self.labels_[self.medoid_indices_[6]] may not be labeled with its corresponding cluster (6).
#   warnings.warn(
# c:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn_extra\cluster\_k_medoids.py:329: UserWarning: Cluster 7 is empty! self.labels_[self.medoid_indices_[7]] may not be labeled with its corresponding cluster (7).
#   warnings.warn(
# c:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn_extra\cluster\_k_medoids.py:329: UserWarning: Cluster 3 is empty! self.labels_[self.medoid_indices_[3]] may not be labeled with its corresponding cluster (3).
#   warnings.warn(
# c:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn_extra\cluster\_k_medoids.py:329: UserWarning: Cluster 6 is empty! self.labels_[self.medoid_indices_[6]] may not be labeled with its corresponding cluster (6).
#   warnings.warn(
# c:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn_extra\cluster\_k_medoids.py:329: UserWarning: Cluster 7 is empty! self.labels_[self.medoid_indices_[7]] may not be labeled with its corresponding cluster (7).
#   warnings.warn(
